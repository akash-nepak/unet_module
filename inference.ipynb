# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import pickle
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import matplotlib.pyplot as plt
from skimage import color
import os
import sys
from safetensors import load_file

# %%
sys.path('/content/drive/MyDrive/unet_module')

from  dataloader import ADE20K
from   model import UNET
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-714805186.py in <cell line: 0>()
# ----> 1 sys.path('/content/drive/MyDrive/unet_module')
#       2
#       3 from  dataloader import ADE20K
#       4 from   model import UNET
#
# NameError: name 'sys' is not defined
